# %%
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('capmetro_UT.csv')
df[:5]
# Out:
#              timestamp  boarding  alighting day_of_week  temperature  \
# 0  2018-09-01 06:00:00         0          1         Sat        74.82
# 1  2018-09-01 06:15:00         2          1         Sat        74.82
# 2  2018-09-01 06:30:00         3          4         Sat        74.82
# 3  2018-09-01 06:45:00         3          4         Sat        74.82
# 4  2018-09-01 07:00:00         2          4         Sat        74.39
#
#    hour_of_day month  weekend
# 0            6   Sep  weekend
# 1            6   Sep  weekend
# 2            6   Sep  weekend
# 3            6   Sep  weekend
# 4            7   Sep  weekend

# %%
df.columns.values
# Out:
# array(['timestamp', 'boarding', 'alighting', 'day_of_week', 'temperature',
#        'hour_of_day', 'month', 'weekend'], dtype=object)

# %%
from datetime import datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
# Figure 2: Ridership vs. Temperature by Month
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="temperature", y="boarding", hue="month", palette="viridis")
plt.title("Ridership vs. Temperature by Month")
plt.xlabel("Temperature (°F)")
plt.ylabel("Number of Boardings")
plt.legend(title="Month")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# Load the data
df = pd.read_csv('capmetro_UT.csv')

# Calculate the rate (boarding - alighting)
df['Rate'] = df['boarding'] - df['alighting']

# Select predictors (excluding timestamp, Rate, boarding, and alighting)
predictors = df.drop(['Rate', 'boarding', 'alighting', 'timestamp'], axis=1)

# One-hot encode categorical variables
predictors = pd.get_dummies(predictors, columns=['day_of_week', 'month', 'weekend'], drop_first=True)

# Add a constant for the intercept term in the model
predictors = sm.add_constant(predictors)

# Fit linear regression model
model = sm.OLS(df['Rate'], predictors).fit()

# Display model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rate   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.350
# Method:                 Least Squares   F-statistic:                     315.1
# Date:                Sun, 13 Aug 2023   Prob (F-statistic):               0.00
# Time:                        13:41:41   Log-Likelihood:                -31367.
# No. Observations:                5824   AIC:                         6.276e+04
# Df Residuals:                    5813   BIC:                         6.283e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            -152.4434      4.701    -32.429      0.000    -161.659    -143.228
# temperature         0.9365      0.072     12.998      0.000       0.795       1.078
# hour_of_day         7.6116      0.157     48.570      0.000       7.304       7.919
# day_of_week_Mon     5.4420      2.617      2.080      0.038       0.313      10.572
# day_of_week_Sat    -2.2584      1.498     -1.508      0.132      -5.195       0.678
# day_of_week_Sun    -0.6358      1.499     -0.424      0.672      -3.575       2.303
# day_of_week_Thu    -0.4995      2.599     -0.192      0.848      -5.594       4.595
# day_of_week_Tue     2.7526      2.607      1.056      0.291      -2.359       7.864
# day_of_week_Wed     1.8717      2.600      0.720      0.472      -3.225       6.968
# month_Oct         -13.2527      1.914     -6.923      0.000     -17.005      -9.500
# month_Sep         -21.0530      2.332     -9.029      0.000     -25.624     -16.482
# weekend_weekend    -2.8941      1.500     -1.930      0.054      -5.834       0.046
# ==============================================================================
# Omnibus:                      185.867   Durbin-Watson:                   0.473
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.711
# Skew:                          -0.384   Prob(JB):                     5.89e-50
# Kurtosis:                       3.587   Cond. No.                     8.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.65e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Extract p-values and coefficients
p_values = model.pvalues.drop('const')  # Exclude constant
coefficients = model.params.drop('const')  # Exclude constant

# Create a table to display the most important predictors
table_data = pd.DataFrame({
    'Predictor': p_values.index,
    'Coefficient': coefficients,
    'P-Value': p_values
})

# Sort the table by p-value (lower p-value indicates greater significance)
table_data = table_data.sort_values(by='P-Value')

# Display the top predictors (you can adjust the number of top predictors to show)
num_top_predictors = 10
print(table_data.head(num_top_predictors))
# Out:
#                        Predictor  Coefficient       P-Value
# hour_of_day          hour_of_day     7.611641  0.000000e+00
# temperature          temperature     0.936463  4.243273e-38
# month_Sep              month_Sep   -21.053028  2.313453e-19
# month_Oct              month_Oct   -13.252699  4.888713e-12
# day_of_week_Mon  day_of_week_Mon     5.442027  3.758593e-02
# weekend_weekend  weekend_weekend    -2.894129  5.365400e-02
# day_of_week_Sat  day_of_week_Sat    -2.258354  1.316549e-01
# day_of_week_Tue  day_of_week_Tue     2.752637  2.911437e-01
# day_of_week_Wed  day_of_week_Wed     1.871723  4.715729e-01
# day_of_week_Sun  day_of_week_Sun    -0.635776  6.715236e-01

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('capmetro_UT.csv')

# Calculate the rate (boarding - alighting)
df['Rate'] = df['boarding'] - df['alighting']

# Group data by month and calculate average temperature, boarding, and alighting
monthly_stats = df.groupby('month')[['temperature', 'boarding', 'alighting']].mean().sort_values(by='temperature', ascending=False)

# Create a bar graph
ax = monthly_stats.plot(kind='bar', figsize=(10, 6))

ax.set_title("Monthly Averages for Temperature, Boarding, and Alighting")
ax.set_xlabel("Month")
ax.set_ylabel("Average Value")
ax.legend(["Average Temperature", "Average Boarding", "Average Alighting"])
ax.set_xticklabels(monthly_stats.index, rotation=45)

plt.tight_layout()
plt.show()

# %%
# Create a mask for weekdays and weekends
weekdays_mask = df['weekend'] == 'weekday'
weekends_mask = df['weekend'] == 'weekend'

# Create a 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)

months = df['month'].unique()

for i, month in enumerate(months):
    month_data = df[df['month'] == month]
    avg_boarding_weekdays = month_data[weekdays_mask]['boarding'].mean()
    avg_boarding_weekends = month_data[weekends_mask]['boarding'].mean()
    
    # Create a bar graph for each month
    axes[i].bar(['Weekdays', 'Weekends'], [avg_boarding_weekdays, avg_boarding_weekends])
    axes[i].set_title(f"Average Boarding for {month}")
    axes[i].set_xlabel("Day Type")
    axes[i].set_ylabel("Average Boarding")
    axes[i].set_ylim(0, df['boarding'].max())  # Set y-axis limit to match the data range

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vb/mgxj4pwj0vv31200pb1k3czm0000gn/T/ipykernel_83013/799971809.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   avg_boarding_weekdays = month_data[weekdays_mask]['boarding'].mean()
# /var/folders/vb/mgxj4pwj0vv31200pb1k3czm0000gn/T/ipykernel_83013/799971809.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   avg_boarding_weekends = month_data[weekends_mask]['boarding'].mean()

# %%
# Create a 1x3 grid of subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)

months = df['month'].unique()

for i, month in enumerate(months):
    month_data = df[df['month'] == month]
    avg_alighting_weekdays = month_data[weekdays_mask]['alighting'].mean()
    avg_alighting_weekends = month_data[weekends_mask]['alighting'].mean()
    
    # Create a bar graph for each month
    axes[i].bar(['Weekdays', 'Weekends'], [avg_alighting_weekdays, avg_alighting_weekends])
    axes[i].set_title(f"Average Alighting for {month}")
    axes[i].set_xlabel("Day Type")
    axes[i].set_ylabel("Average Alighting")
    axes[i].set_ylim(0, df['alighting'].max())  # Set y-axis limit to match the data range

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vb/mgxj4pwj0vv31200pb1k3czm0000gn/T/ipykernel_83013/462740599.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   avg_alighting_weekdays = month_data[weekdays_mask]['alighting'].mean()
# /var/folders/vb/mgxj4pwj0vv31200pb1k3czm0000gn/T/ipykernel_83013/462740599.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   avg_alighting_weekends = month_data[weekends_mask]['alighting'].mean()

# %% [markdown]
# We are going to observe the Monthly Averages for Temperature, Boarding, and Alighting, the Average Boarding for Each of the Months and the Average Alighting for Each of the Months.
#
# Being a frequent user of Cap Metro, prior to plotting the graphs, I had made the hypothese that as the average temperature decreases from the month of September to November, less people would board the bus since the weather would get cooler, discouraging them to use the bus. However, in the graph above, we notice a small increase in the average boarding in the month of October. As more people are boarding the bus, more people will therefore alight the bus.
#
# While it is difficult to state a reason for the increase in boarding and alighting in the month of October, some of the possible factors could be that a lot of events and concerts take place in UT in the month of October, people prefer using the public transportation when the weather is pleasant or because Cap Metro might have given away some promotional offers during the time.
#
# With the Average Boarding and Alighting for each of the months, I wanted to see if there is a change in the average boarding and alighting based on the day of the week however, there was no significant change.
#
# However, based on the graphs above, it is safe to say that temperature or month don't have a significant effect on the average boarding and alighting.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('capmetro_UT.csv')

# Calculate the net passengers (boarding - alighting)
df['NetPassengers'] = df['boarding'] - df['alighting']

# Create a mask for the specified hours
mask = (df['hour_of_day'] > 14) & (df['hour_of_day'] < 18)

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
plt.subplots_adjust(hspace=0.5, wspace=0.3)

# Figure 1: Ridership Trend by Day of Week and Weekend
for day in df['day_of_week'].unique():
    day_data = df[df['day_of_week'] == day]
    avg_rate_by_hour = day_data.groupby('hour_of_day')['NetPassengers'].mean()
    axes[0, 0].plot(avg_rate_by_hour.index, avg_rate_by_hour, label=day)
axes[0, 0].set_title("Average Ridership Trend by Hour of Day and Day of Week")
axes[0, 0].set_xlabel("Hour of Day")
axes[0, 0].set_ylabel("Average Net Passengers (Boarding - Alighting)")
axes[0, 0].legend(title="Day of Week")

# Figure 2: Hourly Ridership Distribution by Month (Difference)
for month in df['month'].unique():
    month_data = df[df['month'] == month]
    avg_rate_by_hour = month_data.groupby('hour_of_day')['NetPassengers'].mean()
    axes[0, 1].plot(avg_rate_by_hour.index, avg_rate_by_hour, label=month)
axes[0, 1].set_title("Average Hourly Ridership Distribution by Hour of Day and Month (Difference)")
axes[0, 1].set_xlabel("Hour of Day")
axes[0, 1].set_ylabel("Average Difference between Alighting and Boarding")
axes[0, 1].legend(title="Month")

# Figure 3: Hourly Ridership Distribution by Day of Week (Difference)
for month in df['month'].unique():
    month_data = df[df['month'] == month]
    avg_rate_by_dow = month_data.groupby('day_of_week')['NetPassengers'].mean()
    axes[1, 1].plot(avg_rate_by_dow.index, avg_rate_by_dow, label=month)
axes[1, 1].set_title("Average Hourly Ridership Distribution by Day of Week and Month (Difference)")
axes[1, 1].set_xlabel("Day of Week")
axes[1, 1].set_ylabel("Average Difference between Alighting and Boarding")
axes[1, 1].legend(title="Month")

# Figure 4: Relationship between Average Rate and Hour of Day (Hour Range: 15-17)
axes[1, 0].set_title("Relationship between Average Net Passengers and Hour of Day (Hour Range: 15-17)")
axes[1, 0].set_xlabel("Hour of Day")
axes[1, 0].set_ylabel("Average Net Passengers (Boarding - Alighting)")
for month in df['month'].unique():
    month_data = df[(df['month'] == month) & mask]
    avg_rate_by_hour = month_data.groupby('hour_of_day')['NetPassengers'].mean()
    axes[1, 0].plot(avg_rate_by_hour.index, avg_rate_by_hour, label=month)
axes[1, 0].legend(title="Month")


plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('capmetro_UT.csv')

# Create a list of unique days of the week
days_of_week = df['day_of_week'].unique()

# Create a grid of subplots based on the number of days
num_cols = 3
num_rows = (len(days_of_week) + num_cols - 1) // num_cols
fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 4 * num_rows))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

# Loop through each day of the week and create a line plot
for i, day in enumerate(days_of_week):
    day_data = df[df['day_of_week'] == day]
    row_idx = i // num_cols
    col_idx = i % num_cols
    sns.lineplot(x='hour_of_day', y='boarding', data=day_data, ax=axes[row_idx, col_idx])
    axes[row_idx, col_idx].set_title(f"Average Boarding for {day}")
    axes[row_idx, col_idx].set_xlabel("Hour of Day")
    axes[row_idx, col_idx].set_ylabel("Average Boarding")
    axes[row_idx, col_idx].set_ylim(0, df['boarding'].max())  # Set y-axis limit to match the data range

# Remove any extra empty subplots
for i in range(len(days_of_week), num_rows * num_cols):
    fig.delaxes(axes[i // num_cols, i % num_cols])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('capmetro_UT.csv')

# Create a list of unique days of the week
days_of_week = df['day_of_week'].unique()

# Create a grid of subplots based on the number of days
num_cols = 3
num_rows = (len(days_of_week) + num_cols - 1) // num_cols
fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 4 * num_rows))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

# Loop through each day of the week and create a line plot
for i, day in enumerate(days_of_week):
    day_data = df[df['day_of_week'] == day]
    row_idx = i // num_cols
    col_idx = i % num_cols
    sns.lineplot(x='hour_of_day', y='alighting', data=day_data, ax=axes[row_idx, col_idx])
    axes[row_idx, col_idx].set_title(f"Average Alighting for {day}")
    axes[row_idx, col_idx].set_xlabel("Hour of Day")
    axes[row_idx, col_idx].set_ylabel("Average Alighting")
    axes[row_idx, col_idx].set_ylim(0, df['alighting'].max())  # Set y-axis limit to match the data range

# Remove any extra empty subplots
for i in range(len(days_of_week), num_rows * num_cols):
    fig.delaxes(axes[i // num_cols, i % num_cols])

plt.tight_layout()
plt.show()

# %% [markdown]
# For the next section, we are going to observe graphs for the Average Boarding and the Average Alighting for each day of the week. As expected, fewer people board and alight the bus on the weekends while on the weekdays, most people alight the bus in the morning between 8AM and 10AM (students arrive to class) and most people board the bus in the afternoon between 3PM and 5PM (students are going back home).
